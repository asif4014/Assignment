# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#Twitter API Authentication variables
consumer_key ='xxxxxxxxxxxxxxxx'
consumer_secret ='xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
access_token ='831419556199555072-376fniopbBWm3eHGFYiXlH5bInoDVRI'
access_token_secret ='kF4G8Krd1VGClIK09dN3dj6pLKI4U25MTWWeOeiIgmGsV'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Kenya', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))

print (tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @EternityTill: #TheMegaVisitation has hit K...
# 1  RT @Ibrah_254: In Kenya, people who use Mobile...
# 2  @Amuty @_Myrabel_ Looking forward to your revi...
# 3  RT @Tabby254: increased access to mobile money...
# 4  @ImamMahdyImran @RabbitTheKing Eeeh kama unach...
# 5  RT @CisNyakundi: Dr. Phil had to come through ...
# 6  RT @jumaf3: Coffee from Rwanda is doing better...
# 7  RT @deCOALonize: As we look to nature based so...
# 8  Maafisa wa Kaunti ya Kakamega, #Kenya wamefuku...
# 9  @lovellab55 ........ i own a doujin about them...
# 2019-08-14 13:24:56

# %%
import nltk
nltk.download('vader lexicon')
# Out:
# [nltk_data] Error loading vader lexicon: Package 'vader lexicon' not
# [nltk_data]     found in index
# False

# %%
sid = SentimentIntensityAnalyzer()

listy =[]

for index,row in data.iterrows():
    ss = sid.polarity_scores(row["Tweets"])
    listy.append(ss)
    
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @EternityTill: #TheMegaVisitation has hit K...
# 1   RT @Ibrah_254: In Kenya, people who use Mobile...
# 2   @Amuty @_Myrabel_ Looking forward to your revi...
# 3   RT @Tabby254: increased access to mobile money...
# 4   @ImamMahdyImran @RabbitTheKing Eeeh kama unach...
# 5   RT @CisNyakundi: Dr. Phil had to come through ...
# 6   RT @jumaf3: Coffee from Rwanda is doing better...
# 7   RT @deCOALonize: As we look to nature based so...
# 8   Maafisa wa Kaunti ya Kakamega, #Kenya wamefuku...
# 9   @lovellab55 ........ i own a doujin about them...
# 10  #WeedLovesYou \n\n Model | @kendra_the_funky_h...
# 11  RT @cmasio: ‘@KenGenKenya believes in investin...
# 12                    @ysn__mg ギブしようとしたけど身体が戦ってしまいました
# 13  RT @Amuty: @_Myrabel_ @SafeBoda_Kenya This mea...
# 14  DEG DEG Somalia Oo Ka Qaylasiisay Kenya Iyo Ke...
# 15  I have a dream, I have a vision, I am seeing a...
# ...
